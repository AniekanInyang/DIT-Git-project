# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


#weight-height.csv
#load the data

# df = pd.read_csv("weight-height.csv")
# df.drop("Gender", axis = 1, inplace=True)
# new_df = df[['Weight','Height']]
# new_df

df = pd.read_csv("weight-height.csv", header=None, skiprows=1)
new_df = df.drop(columns=0)
new_df = df[[2, 1]] # i change their position by their index position and then save as new_weight.csv
new_df.to_csv('new_weight.csv', index = False)


X = []
Y = []
for line in open("new_weight.csv"):
    x, y = line.split(',')
    X.append(float(x))
    Y.append(float(y))
    
#Turning X and Y into numpy arrays
X = np.array(X)
Y = np.array(Y)

#plot to see what it looks like
plt.scatter(X, Y)
plt.show()

# apply the equations we learned to calculate

denominator = X.dot(X) - X.mean() * X.sum()
a = (X.dot(Y) - Y.mean() * X.sum() ) / denominator
b = (Y.mean() * X.dot(X) - X.mean() * X.dot(Y) ) / denominator

#to calculte the predicted y
Yhat = a * X + b

#plot it all
plt.scatter(X, Y)
plt.plot(X, Yhat)
plt.show()

#Calculate r-squared for number 1
d1 = Y - Yhat
d2 = Y - Y.mean() 
r2_one = 1 - d1.dot(d1) / d2.dot(d2)
print("the r-squared for quastion 1 is: ", r2_one)
# Out:
# the r-squared for quastion 1 is:  0.8443354927385464

# %% [markdown]
# # 2

# %%
#Calculation of maximum likelihood


X = []
Y = []
for line in open("new_weight.csv"):
    x, y = line.split(',')
    X.append(float(x))
    Y.append(float(y))
    

X = np.linspace(0, 10, N) #leaving space points between 0 and 10
Y = 0.5*X + np.random.randn(N)
# np.concatenate((x,y[:,None]),axis=1)

# #make outliers
# Y[-1] += 10
# Y[-2] += 10

X = np.vstack([np.ones(N), X]).T

w_ml = np.linalg.solve(X.T.dot(X), X.T.dot(Y))
Yhat_ml = X.dot(w_ml)

# %% [markdown]
# # 3

# %%
#graph of maximum likelihood
plt.scatter(X[:,1], Y)
plt.plot(X[:,1], Yhat_ml)
plt.show()

#Calculate r-squared for number 2
d1 = Y - Yhat_ml
d2 = Y - Y.mean() 
r2 = 1 - d1.dot(d1) / d2.dot(d2)
print("the r-squared for question 2 is: ", r2)
# Out:
# the r-squared for question 2 is:  0.6757123910065677

# %% [markdown]
# # 4

# %%
print("the r-squared for question 1 is: ", r2_one)
print("the r-squared for question 2 is: ", r2)
# Out:
# the r-squared for question 1 is:  0.8443354927385464
# the r-squared for question 2 is:  0.6757123910065677

# %% [markdown]
# # 5

# %% [markdown]
# # r2 = 1 - (sum of squared residual / sum of squared total)
# we can increase the value of r2 through the introduction of <b>random noise</b><br>
# which also helps in proper prediction of our target.
# Theoritically, the randomly generated noise is expected to be uncorrelated with the traget<br>
# Hence, the expected correlation between the random noise and the output(target) is non-zero which increase the alue of r2
