# %% [markdown]
# # ASSESSMENT
#     Data: 1. articles.csv - contains 1000 articles that cuta cross      various fields
#     Data: 2. google-phd-program.txt - a short article on google's proposed new PhD program.
#     Data: 3. comment.txt - A comment to google article.
#
#     Data: 4. oliver-twist-0-9.txt - Chapters 1-9 of the charles dickens popular book Oliver Twist
#
#
#     Instruction: Read the command in each cell and write code to give the same output

# %% [markdown]
# # A) Regular Expressions

# %%
# Import standrad libraries to injest the CSV file and read in the CSV file
import pandas as pd
art = pd.read_csv("articles.csv")
# art.head(5)
# Out:
#    id                                           articles
# 0   1  What does it mean to be successful? Perhaps, o...
# 1   2  Much has been made of Africa&rsquo;s unfavorab...
# 2   3  A few days after a Damaris Wambui Kamau and he...
# 3   4  \n\n\n\nJust a few hours after their release o...
# 4   5  IPOA is investigating the murder of four peopl...

# %%
#View the data
art.tail(5)
# Out:
#        id                                           articles
# 996   980  President Muhammadu Buhari has appointed Dr Th...
# 997   981  The Federal Inland Revenue Service (FIRS) said...
# 998   982  Airtel Nigeria has officially apply with the S...
# 999   983  The Management of Forte oil plc has appointed ...
# 1000  984  The President of Dangote Group, Aliko Dangote ...

# %%
# Count the email addresses contained in entire dataset
data = art["articles"]
# data.value_counts()
# data.count()
new_data = data.to_string()
new_data
# Out:
# '0       What does it mean to be successful? Perhaps, o...\n1       Much has been made of Africa&rsquo;s unfavorab...\n2       A few days after a Damaris Wambui Kamau and he...\n3       \\n\\n\\n\\nJust a few hours after their release o...\n4       IPOA is investigating the murder of four peopl...\n5       Former President Jerry John Rawlings has calle...\n6       David L. Poulson who served in Erie in North P...\n7       In what started as a campaign strategy to a pr...\n8       \\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\n\\nThe fight for position...\n9       Much has been made of Africa&rsquo;s unfavorab...\n10      Kenyans planning to travel to the UK can now b...\n11      African E-comerce giants Jumia has filed to be...\n12      Central bank of Kenya governor Patrick Njoroge...\n13      The Data Protection Commission will soon probe...\n14      Following the tragic terror attack in Newzeala...\n15      Another corruption scandal involving the gover...\n16      On 14th February, 2019, Marek &ldquo;Chinedu&r...\n17      The face off began and ended with a 2-0 victor...\n18      Globalisation is a good thing, they said...! W...\n19      Manchester United were 2-0 down from the first...\n20      Real Madrid president Florentino Perez is prep...\n21      A fan wanted a picture with Ultimate Fighting ...\n22      So, we have a knife crime problem? And the epi...\n23      The Parliament of Ghana has began processes to...\n24      Sooo Conor McGregor randomly announces that he...\n25      The Red Devils face one of the toughest teams ...\n26      UFC bantamweight champion T.J dillashaw issued...\n27      A second loss at Wolves in 17 days has left Ma...\n28      Super Falcons forward Asisat Oshoala is happy ...\n29      Ajax Amsterdam followed up their elimination o...\n30      It&rsquo;s the second leg, Barcelona VS Manche...\n31      BREXIT... it\'s almost a new phenomenon, a grou...\n32      Jurgen Klopp hinted that he didn\'t believe Liv...\n33      Just 24 hours afterLiverpool pulled off a come...\n34      The United States won the Women\'s World Cup fo...\n35      Kenyacame from behind twice to beat neighbours...\n36      Kenyan National team Harambee Stars startled i...\n37      Essentially, this is an obnoxious question tha...\n38      Nigeria music star, Adekunle Gold is celebrati...\n39      Never did anyone think of a worldwide destruct...\n40      During the start of the century when the agric...\n41      Bosasa now known as African Global Operations ...\n42      President Cyril Ramaphosa delived the annual s...\n43      On Monday 18th February South African restaura...\n44      Kane converted from a penalty spot few minutes...\n45      Super charged Liverpool ran riot at the Allian...\n46      In overturning a two-goal deficit carried over...\n47      Fenerbahce completed a 2-1 comeback versus Siv...\n48      Arsenal&rsquo;s free scoring Folarin Balogun n...\n49      A court in Hong Kong on Wednesday sentenced ei...\n50      The All Progressives Congress (APC) Presidenti...\n51      Alex Iwobi is set to continue in his midfield ...\n52      Super Eagles gaffer and former defender of the...\n53      Garry Southgate announced the latest Three Lio...\n54      By the end of the night, the Argentine warlord...\n55      The sum of N9.2bn have been approve by the Fed...\n56      Jose Mourinho has revealed that he has, in the...\n57      Nigeria&rsquo;s Asisat Oshoala and Equatorial ...\n58      Arsenal legend and two-time African player of ...\n59      Super Eagles gaffer Gernot Rohr has said he pl...\n60      The former super eagles star who is on loan to...\n61      UEFA has resolved to fine the Juventus talisma...\n62      Trifling fissures really are necessary for spr...\n63      Middlesbrough were, on Saturday, invited to th...\n64      2-0 score line ensures Chelsea suffered a heav...\n65      Oshoala Returns to Training after Four Weeks o...\n66      Kingdom of snakes have been exhibiting some hi...\n67      Who would&rsquo;ve  ...

# %%
# import standard package
import re 

# Enter your regex pattern here. This may take several tries!
pattern = r'\w+@\w+.\w{3}'
# //r'[\w\.-]+@[\w\.-]+'//
reg = re.findall(pattern, new_data)
abc = len(reg)
print(abc)
# Out:
# 0

# %% [markdown]
# # NLP Basics

# %%
# Run this cell to perform standard imports
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Create an article object from the 'google-phd-program.txt' file

with open('google-phd-program.txt', encoding="utf8") as f:
    doc = nlp(f.read())

# %%
# How many sentences are conatined in the file
len([sent for sent in doc.sents])
# Out:
# 24

# %%
# Print out the FOURTEENTH sentence
# for sent in doc.sents:
#     print([14])
# doc_sents = [sent for sent in doc.sents]
# doc_sents
# doc_sents = [sent for sent in doc.sents]
# list(doc.sents)

# for sent in doc.sents:
#     print(sent)
sentence = list(doc.sents)[13]
sentence
# Out:
# Instead of receiving a boring paper diploma at the end of their PhDs, Google PhD graduates receive a priceless note handwritten by Jeff Dean on a napkin that says, “You have a PhD now.

# %%
# For each token in the sentence above, print its text, POS tag,
# dep tag and lemma. 
#Have values line up in columns like in the print output.
for token in sentence:
    print(f'{token.text:{10}} {token.pos_:{8}} {token.tag_:{6}} {token.dep_:{6}} {token.lemma_:{6}} ')
# Out:
# Instead    ADV      RB     advmod instead
# of         ADP      IN     prep   of
# receiving  VERB     VBG    pcomp  receive
# a          DET      DT     det    a
# boring     ADJ      JJ     amod   boring
# paper      NOUN     NN     compound paper
# diploma    NOUN     NN     dobj   diploma
# at         ADP      IN     prep   at
# the        DET      DT     det    the
# end        NOUN     NN     pobj   end
# of         ADP      IN     prep   of
# their      ADJ      PRP$   poss   -PRON-
# PhDs       PROPN    NNP    pobj   phds
# ,          PUNCT    ,      punct  ,
# Google     PROPN    NNP    compound google
# PhD        NOUN     NN     compound phd
# graduates  VERB     VBZ    nsubj  graduate
# receive    VERB     VBP    ROOT   receive
# a          DET      DT     det    a
# priceless  ADJ      JJ     amod   priceless
# note       NOUN     NN     dobj   note
# handwritten ADJ      JJ     acl    handwritten
# by         ADP      IN     agent  by
# Jeff       PROPN    NNP    compound jeff
# Dean       PROPN    NNP    pobj   dean
# on         ADP      IN     prep   on
# a          DET      DT     det    a
# napkin     NOUN     NN     pobj   napkin
# that       ADJ      WDT    nsubj  that
# says       VERB     VBZ    relcl  say
# ,          PUNCT    ,      punct  ,
# “          PUNCT    ``     punct  "
# You        PRON     PRP    nsubj  -PRON-
# have       VERB     VBP    ccomp  have
# a          DET      DT     det    a
# PhD        NOUN     NN     dobj   phd
# now        ADV      RB     advmod now
# .          PUNCT    .      punct  .

# %%
# Extract entites in the SECOND sentence
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
    else:
        print('No named entities found.')
sentence = list(doc.sents)[1]
show_ents(sentence)
# Out:
# Google Brain - PERSON - People, including fictional
# DeepMind - GPE - Countries, cities, states
# FAIR - ORG - Companies, agencies, institutions, etc.
# Stanford - ORG - Companies, agencies, institutions, etc.
# Berkeley - GPE - Countries, cities, states
# MIT - ORG - Companies, agencies, institutions, etc.

# %%
# Write a matcher called 'AI' that finds all occurrences
# of the phrase "Artificial Intelligence" and word 'AI' in the article

# First Run this standard import and call
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

# %%
# Create the patterns and add it to matcher:
pattern1 = [{'LOWER': 'ai'}]
pattern2 = [{'LOWER': 'artificial intelligence'}]
pattern3 = [{'LOWER': 'artificial'}, {'IS_SPACE': True, 'OP':'*'},  {'LOWER': ' intelligence'}]
pattern4 = [{'LOWER': 'artificial intelligence'}, {'LOWER': 'ai'}]
# pattern3 = [{'LOWER': 'swimming'}, {'LOWER': 'vigorously'}]

matcher.add('artificial', None, pattern1, pattern2, pattern3, pattern4)

# %%
# Create a list of matches called "found_matches" and print the list:
found_matches = matcher(doc)
print(found_matches)
# Out:
# [(16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 12, 13), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 138, 139), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 285, 286), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 408, 409), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 421, 422), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459), (16051026535560969536, 458, 459)]

# %%
print(doc[47:60])
# Out:
# artificial intelligence research community, publishing as many papers (if not more

# %%
# Write a FUNCTION that takes in a index and prints the sentence
#in which the match at that index is found

for sent in doc.sents:
        if found_matches[3][1] < sent.end:
            print(sent)
            break
# Out:
# In a move that is completely unsurprising to many, Google’s AI research division has announced that they are issuing PhD degrees to select employees.

# %%
# print the sentence where the FOURTH match is 
# print(sents)

# %%
# print the sentence where the last match is 
for sent in doc.sents:
        if found_matches[70][1] < sent.end:
            print(sent)
            break
# Out:
# In the meantime, Google is already planning for the next way to find top AI talent.

# %% [markdown]
# ## POS Tagging

# %%
# RUN THIS CELL to perform standard imports:
from spacy import displacy

# %%
# Provide a frequency list of POS tags from the entire article
POS_counts = doc.count_by(spacy.attrs.POS)

for k,v in sorted(POS_counts.items()):
    print(f'{k}. {doc.vocab[k].text:{5}}: {v}')
# Out:
# 83. ADJ  : 48
# 84. ADP  : 56
# 85. ADV  : 22
# 88. CCONJ: 11
# 89. DET  : 30
# 90. INTJ : 1
# 91. NOUN : 116
# 92. NUM  : 3
# 93. PART : 15
# 94. PRON : 10
# 95. PROPN: 37
# 96. PUNCT: 62
# 99. VERB : 71
# 102. SPACE: 6

# %%
# What percentage of tokens are nouns?
percent = 100*POS_counts[91]/len(doc)
print(percent)
# Out:
# 23.770491803278688

# %%
list_of_sents = [nlp(sent.text) for sent in doc.sents]
list_of_ners = [doc for doc in list_of_sents if doc.ents]
len(list_of_ners)
# Out:
# 19

# %%
# Display the named entity visualization for the entire article
from spacy import displacy
displacy.render(list_of_sents, style='ent', jupyter=True)

# for sent in doc.sents:
#     displacy.render(nlp(sent.text), style='ent', jupyter=True)
# Out:
# C:\Users\Maxwell\Anaconda3\envs\nlp_course\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\Maxwell\Anaconda3\envs\nlp_course\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\Maxwell\Anaconda3\envs\nlp_course\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\Maxwell\Anaconda3\envs\nlp_course\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\Maxwell\Anaconda3\envs\nlp_course\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <div class="entities" style="line-height: 2.5">In a move that is completely unsurprising to many,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  research division has announced that they are issuing
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     PhD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  degrees to select employees.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
#
# <div class="entities" style="line-height: 2.5">Industry research organizations like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google Brain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     DeepMind
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     FAIR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are well known as heavy hitters in the artificial intelligence research community, publishing as many papers (if not more) as academic institutions like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Stanford
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Berkeley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     MIT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5">Many top professors from academia have migrated over to industry research labs as well, sacrificing the security of academic tenure for fat stacks of money.</div>
#
# <div class="entities" style="line-height: 2.5">Although
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has previously experimented with research residencies, this is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time that they have issued postgraduate degrees.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>
#
# <div class="entities" style="line-height: 2.5">According to a representative, the tech giant decided to issue
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     PhDs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in order to attract scarce
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  talent.</div>
#
# <div class="entities" style="line-height: 2.5">“</div>
#
# <div class="entities" style="line-height: 2.5">It’s extremely difficult to find people with talent in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Machine Learning and Artificial Intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     these days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and it pained us to see so many of our amazing interns decline our return offers to go back to school for
# <mark class="entity" s

# %% [markdown]
# # OPTIONAL : Which named entity do you think is not well tagged
# Google phd
# # Answer here and why:
# Google phd where Law entity was assign. This is because the contextual meaning of the "word Google phd" has nothing
# to do with law

# %% [markdown]
# ## Perform VADER Sentiment Analysis on the Comment file

# %%
# Import SentimentIntensityAnalyzer and create an sid object
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
# kindly ignore the warning

# %%
# using 'open' read in the comment.txt file 
# with open('comment.txt', encoding="utf8") as f:
#     doc = nlp(f.read())

with open('comment.txt') as c:
    fields = c.read()

    
# Run fields to see the contents of contacts.txt:
# fields

# %%
with open('comment.txt') as c:
    fields = c.read()

    
# Run fields to see the contents of contacts.txt:
fields
# Out:
# 'Interesting Concept.\nIndustry does not have the patience to wait for students to graduate from their respective schools.\nThe topic of research will be driven by the firm, which means that it would be one small cog/nut in the firmâ€™s vast service offering.\nThe absence of freedom to choose their own topic of research might be detrimental to innovation in the long run.\nInnovation, if it happens, will be incremental.\nWe can forget about path breaking discoveries.'

# %%
# Obtain the sid scores for the comment
sid.polarity_scores(fields)
# Out:
# {'neg': 0.022, 'neu': 0.809, 'pos': 0.17, 'compound': 0.9186}

# %%
# Write fucntion to take in a comment and returns whether it was 
# "Positive", "Negative" or "Neutral"


def comment_sentiment(comment):
    scores = sid.polarity_scores(comment)
    if scores['compound'] == 0:
        return 'Neutral'
    elif scores['compound'] > 0:
        return 'Positive'
    else:
        return 'Negative'

# %%
# Write a comment of the article (AFTER READING IT please) as one continuous string or (multiple sentences are ok)
comments = 'I think the math works out well for google as they get to have great talent working for them, but I\'m not sure if its gonna be a fufilling experience for the grad'

# %%
# Test your function on your comment above:
comment_sentiment(comments)
# Out:
# 'Positive'

# %% [markdown]
# # Topic Modelling with LDA and NMF
# First we'd look at LDA then NMF and at the end see how both pan out.

# %% [markdown]
# # Preprocessing for LDA
# Task: Use Count Vectorization to create a vectorized document sparse matrix. Use a max_df=0.9 and min_df=2 parameters.

# %%
# Import the required packages i.e Countvectorizer, LDA

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Using the CV object, Fit and transform the countvectorizer 
# on the articles using the params giving above
cv = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
dtm = cv.fit_transform(art['articles'])
dtm
# Out:
# <1001x10339 sparse matrix of type '<class 'numpy.int64'>'
# 	with 109044 stored elements in Compressed Sparse Row format>

# %%
#Fit LDA object to the sparse matrix fron the count vectorizer
# Extracting 10 TOPICS with a RANDOM STATE of 10
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=10,random_state=10)
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='batch', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_components=10, n_jobs=None, n_topics=None, perp_tol=0.1,
#              random_state=10, topic_word_prior=None,
#              total_samples=1000000.0, verbose=0)

# %%
# View the the TOP 20 words of the all Topics 
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([cv.get_feature_names()[i] for i in topic.argsort()[-20:]])
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['nigerian', 'police', 'south', 'statement', 'federal', 'according', 'states', 'national', 'security', 'buhari', 'people', 'nigeria', 'state', 'country', 'government', 'rsquo', 'president', 'rdquo', 'said', 'ldquo']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['general', 'rsquo', 'capital', 'market', 'business', 'programme', 'new', '2019', 'sec', 'rdquo', 'nigerian', 'nigeria', 'african', 'development', 'commission', 'company', '000', 'ldquo', 'africa', 'said']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['officers', '000', 'year', 'air', 'airlines', 'million', 'new', 'according', 'army', 'police', 'oil', 'project', 'government', 'state', 'nigeria', 'nigerian', 'rdquo', 'rsquo', 'ldquo', 'said']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['year', 'respondent', 'server', 'candidate', 'president', 'rdquo', 'apc', 'party', 'national', 'plastic', 'atiku', 'results', 'said', 'buhari', 'inec', 'rsquo', 'pdp', 'election', 'ldquo', 'presidential']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['energy', 'increase', 'africa', 'government', 'new', 'tax', 'market', 'agency', 'development', 'state', 'nnpc', 'national', 'million', 'according', 'gas', 'nigeria', 'rdquo', 'rsquo', 'ldquo', 'said']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['match', 'club', 'egypt', 'group', 'rohr', '2019', 'time', 'ldquo', 'world', 'game', 'rdquo', 'nations', 'players', 'africa', 'nigeria', 'team', 'rsquo', 'super', 'cup', 'eagles']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['parties', 'nigeria', 'buhari', 'pdp', 'people', 'political', 'presidential', 'court', 'state', 'inec', 'electoral', 'commission', 'party', 'president', 'elections', 'rsquo', 'rdquo', 'ldquo', 'said', 'election']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['2019', 'stock', 'banks', 'years', 'report', '2018', 'said', 'shares', 'company', 'year', 'cbn', 'mtn', 'market', 'according', 'exchange', 'billion', 'percent', 'million', 'nigeria', 'bank']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['world', 'child', 'new', 'singer', 'instagram', 'love', 'don', 'man', 'know', 'years', 'time', 'life', 'people', 'just', 'like', 'said', 'lsquo', 'rdquo', 'ldquo', 'rsquo']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['minute', 'manchester', 'city', 'second', 'half', 'minutes', 'win', 'premier', 'arsenal', 'champions', 'united', 'team', 'game', 'club', 'season', 'goals', 'goal', 'chelsea', 'rsquo', 'league']

# %%
# Transform the sparse data on the fitted LDA object
topic_results = LDA.transform(dtm)

# Create a new column called 'Topic_lda' and save the Topic id's in it

art["Topic_lda"] = topic_results.argmax(axis=1)

# %%
# View the dataframe now
art.head()
# Out:
#    id                                           articles  Topic_lda lda_Label
# 0   1  What does it mean to be successful? Perhaps, o...          3  election
# 1   2  Much has been made of Africa&rsquo;s unfavorab...          4     stock
# 2   3  A few days after a Damaris Wambui Kamau and he...          0  election
# 3   4  \n\n\n\nJust a few hours after their release o...          0   economy
# 4   5  IPOA is investigating the murder of four peopl...          0   economy

# %%
# Create a label dictionary for each topic, kinda like mine,
#please go through the words in each topic to figure out a fitting 
#label for that topic and create a dictionary mapping each topic id 
#to its corresponding label (which is at your discretion)

label_dict = {
    0:'security',
    1:'economy',
    2:'economy',
    3:'election',
    4:'economy',
    5:'football',
    6:'election',
    7:'stock',
    8:'social',
    9:'football'
}

# there seem to be just 6 unique labels

# %%
# Create a new column called 'lda_labels' based on the map created above
art['lda_Label'] = art['Topic_lda'].map(label_dict)
art.head()
# Out:
#    id                                           articles  Topic_lda lda_Label
# 0   1  What does it mean to be successful? Perhaps, o...          3  election
# 1   2  Much has been made of Africa&rsquo;s unfavorab...          4   economy
# 2   3  A few days after a Damaris Wambui Kamau and he...          0  security
# 3   4  \n\n\n\nJust a few hours after their release o...          0  security
# 4   5  IPOA is investigating the murder of four peopl...          0  security

# %% [markdown]
# # Preprocessing for NMF
# Task: Use TF-IDF Vectorization to create a vectorized document term matrix. Use a max_df=0.9 and min_df=2 parameters.

# %%
# Import the required packages i.e tfidfvectorizer, NMF

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
# Fit and transform the tfidfvectorizer on the articles using the params giving above
tfidf = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
dtm = tfidf.fit_transform(art["articles"])
dtm
# Out:
# <1001x10339 sparse matrix of type '<class 'numpy.float64'>'
# 	with 109044 stored elements in Compressed Sparse Row format>

# %%
# Fit an NMF instance to the sparse matrix from the tfidfvectorizer
# Extracting 10 topics with a random state of 10
nmf_model = NMF(n_components=10,random_state=10)
nmf_model.fit(dtm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=10, random_state=10, shuffle=False, solver='cd', tol=0.0001,
#   verbose=0)

# %%
# View the the TOP 20 words of the all Topics 
for index,topic in enumerate(nmf_model.components_):
    print(f'THE TOP 20 WORDS FOR TOPIC #{index}')
    print([cv.get_feature_names()[i] for i in topic.argsort()[-20:]])
    print('\n')
# Out:
# THE TOP 20 WORDS FOR TOPIC #0
# ['national', 'administration', 'governors', 'federal', 'herdsmen', 'army', 'north', 'military', 'nigerians', 'people', 'rdquo', 'nigeria', 'security', 'said', 'buhari', 'state', 'country', 'ldquo', 'government', 'president']
#
#
# THE TOP 20 WORDS FOR TOPIC #1
# ['obi', 'match', 'burundi', 'injury', 'ighalo', 'coach', 'group', 'gernot', 'afcon', 'nigeria', 'egypt', 'mikel', 'nations', 'players', 'team', 'africa', 'rohr', 'cup', 'super', 'eagles']
#
#
# THE TOP 20 WORDS FOR TOPIC #2
# ['official', 'long', 'just', 'singer', 'man', 'songs', 'people', 'really', 'new', 'want', 'time', 'like', 'feel', 'world', 'don', 've', 'music', 'hellip', 'lsquo', 'rsquo']
#
#
# THE TOP 20 WORDS FOR TOPIC #3
# ['oil', 'plc', 'board', 'investors', 'million', 'said', 'percent', 'securities', 'billion', 'nigeria', 'nse', 'stock', 'commission', 'sec', 'shares', 'listing', 'exchange', 'market', 'mtn', 'company']
#
#
# THE TOP 20 WORDS FOR TOPIC #4
# ['goals', 'window', 'appearances', 'old', 'deal', 'city', 'summer', 'international', 'turkish', 'fenerbahce', 'player', 'premier', 'year', 'transfer', 'loan', 'moses', 'league', 'club', 'season', 'chelsea']
#
#
# THE TOP 20 WORDS FOR TOPIC #5
# ['ldquo', 'abubakar', 'votes', 'democratic', 'national', 'said', 'state', 'president', 'candidate', 'commission', 'apc', 'buhari', 'atiku', 'presidential', 'electoral', 'pdp', 'elections', 'party', 'inec', 'election']
#
#
# THE TOP 20 WORDS FOR TOPIC #6
# ['score', 'arsenal', 'scored', 'liverpool', 'united', 'falcons', 'team', 'second', 'half', 'final', 'minutes', 'goals', 'match', 'barcelona', 'champions', 'win', 'minute', 'league', 'goal', 'game']
#
#
# THE TOP 20 WORDS FOR TOPIC #7
# ['time', 'people', 'old', 'like', 'love', 'god', 'just', 'know', 'wrote', 'police', 'instagram', 'actor', 'children', 'life', 'ndash', 'family', 'rsquo', 'said', 'rdquo', 'ldquo']
#
#
# THE TOP 20 WORDS FOR TOPIC #8
# ['growth', 'merger', 'loans', 'development', 'nexim', 'sector', 'central', 'billion', 'customers', 'said', 'banking', 'plc', 'emefiele', 'nigeria', 'access', 'diamond', 'financial', 'banks', 'cbn', 'bank']
#
#
# THE TOP 20 WORDS FOR TOPIC #9
# ['known', 'boys', 'fashola', 'nigerian', 'davido', 'musician', 'ldquo', 'guilty', 'money', 'jail', 'justice', 'bail', 'crimes', 'singer', 'fraud', 'court', 'yahoo', 'naira', 'efcc', 'marley']

# %%
# Transforn the data on the fitted NMF instance
topic_results = nmf_model.transform(dtm)

# Create a new column called Topic_nmf and save the Topic id's in it
art["Topic_nmf"] = topic_results.argmax(axis=1)
art.head()
# Out:
#    id                                           articles  Topic_lda lda_Label  \
# 0   1  What does it mean to be successful? Perhaps, o...          3  election
# 1   2  Much has been made of Africa&rsquo;s unfavorab...          4   economy
# 2   3  A few days after a Damaris Wambui Kamau and he...          0  security
# 3   4  \n\n\n\nJust a few hours after their release o...          0  security
# 4   5  IPOA is investigating the murder of four peopl...          0  security
#
#    Topic_nmf
# 0          2
# 1          3
# 2          7
# 3          7
# 4          7

# %%
#Using the same set of labels now rearrange them to suit the topics 
#i.e if topic 7 for lda was labeled election, but now topic 7 looks 
#to be social, then modify the labels_dict accordingly to suit NMF

label_dict = {
    0:'security',
    1:'football',
    2:'social',
    3:'stock',
    4:'football',
    5:'election',
    6:'football',
    7:'social',
    8:'economy',
    9:'social'
}
# maintaining the six unique labels

# %%
# Create a new column called lda_labels based on the map created above
art['nmf_Label'] = art['Topic_nmf'].map(label_dict)
art.head()
# Out:
#    id                                           articles  Topic_lda lda_Label  \
# 0   1  What does it mean to be successful? Perhaps, o...          3  election
# 1   2  Much has been made of Africa&rsquo;s unfavorab...          4   economy
# 2   3  A few days after a Damaris Wambui Kamau and he...          0  security
# 3   4  \n\n\n\nJust a few hours after their release o...          0  security
# 4   5  IPOA is investigating the murder of four peopl...          0  security
#
#    Topic_nmf nmf_Label
# 0          2    social
# 1          3     stock
# 2          7    social
# 3          7    social
# 4          7    social

# %%
# How many of the articles share the same label 
# len(art["lda_Label"] == art["nmf_Label"])
count_lda = art["lda_Label"].value_counts()
count_lda
# Out:
# football    295
# security    223
# social      174
# economy     151
# election    110
# stock        48
# Name: lda_Label, dtype: int64

# %%
count_lda.max()
# Out:
# 295

# %%
count_nmf = art["nmf_Label"].value_counts()
count_nmf.max()
# Out:
# 334

# %%
similar = art.where(art["lda_Label"] == art["nmf_Label"])
new_similar = similar.dropna(how="any")
new_similar.head()
# Out:
#         id                                           articles  Topic_lda  \
# 5   1436.0  Former President Jerry John Rawlings has calle...        0.0
# 17    16.0  The face off began and ended with a 2-0 victor...        9.0
# 19    18.0  Manchester United were 2-0 down from the first...        9.0
# 20    19.0  Real Madrid president Florentino Perez is prep...        9.0
# 24    23.0  Sooo Conor McGregor randomly announces that he...        8.0
#
#    lda_Label  Topic_nmf nmf_Label
# 5   security        0.0  security
# 17  football        6.0  football
# 19  football        6.0  football
# 20  football        4.0  football
# 24    social        2.0    social

# %%
len(new_similar)
# Out:
# 650

# %%
# What % of our articles were labelled with the same label by both topic models
percent = 100*len(new_similar)/len(art)
percent
# Out:
# 64.93506493506493

# %% [markdown]
# # Optional Challenge: Text Generation with Neural Networks

# %%
# Read in the oliver-twist-0-9.txt text
with open('oliver-twist-0-9.txt') as c:
    fields = c.read()

    
# Run fields to see the contents of contacts.txt:
fields
# Out:
# 'TREATS OF THE PLACE WHERE OLIVER TWIST WAS BORN AND OF THE\nCIRCUMSTANCES ATTENDING HIS BIRTH\n\nAmong other public buildings in a certain town, which for many reasons\nit will be prudent to refrain from mentioning, and to which I will\nassign no fictitious name, there is one anciently common to most towns,\ngreat or small: to wit, a workhouse; and in this workhouse was born; on\na day and date which I need not trouble myself to repeat, inasmuch as\nit can be of no possible consequence to the reader, in this stage of\nthe business at all events; the item of mortality whose name is\nprefixed to the head of this chapter.\n\nFor a long time after it was ushered into this world of sorrow and\ntrouble, by the parish surgeon, it remained a matter of considerable\ndoubt whether the child would survive to bear any name at all; in which\ncase it is somewhat more than probable that these memoirs would never\nhave appeared; or, if they had, that being comprised within a couple of\npages, they would have possessed the inestimable merit of being the\nmost concise and faithful specimen of biography, extant in the\nliterature of any age or country.\n\nAlthough I am not disposed to maintain that the being born in a\nworkhouse, is in itself the most fortunate and enviable circumstance\nthat can possibly befall a human being, I do mean to say that in this\nparticular instance, it was the best thing for Oliver Twist that could\nby possibility have occurred.  The fact is, that there was considerable\ndifficulty in inducing Oliver to take upon himself the office of\nrespiration,--a troublesome practice, but one which custom has rendered\nnecessary to our easy existence; and for some time he lay gasping on a\nlittle flock mattress, rather unequally poised between this world and\nthe next: the balance being decidedly in favour of the latter.  Now,\nif, during this brief period, Oliver had been surrounded by careful\ngrandmothers, anxious aunts, experienced nurses, and doctors of\nprofound wisdom, he would most inevitably and indubitably have been\nkilled in no time.  There being nobody by, however, but a pauper old\nwoman, who was rendered rather misty by an unwonted allowance of beer;\nand a parish surgeon who did such matters by contract; Oliver and\nNature fought out the point between them.  The result was, that, after\na few struggles, Oliver breathed, sneezed, and proceeded to advertise\nto the inmates of the workhouse the fact of a new burden having been\nimposed  upon the parish, by setting up as loud a cry as could\nreasonably have been expected from a male infant who had not been\npossessed of that very useful appendage, a voice, for a much longer\nspace of time than three minutes and a quarter.\n\nAs Oliver gave this first proof of the free and proper action of his\nlungs, the patchwork coverlet which was carelessly flung over the iron\nbedstead, rustled; the pale face of a young woman was raised feebly\nfrom the pillow; and a faint voice imperfectly articulated the words,\n\'Let me see the child, and die.\'\n\nThe surgeon had been sitting with his face turned towards the fire:\ngiving the palms of his hands a warm and a rub alternately.  As the\nyoung woman spoke, he rose, and advancing to the bed\'s head, said, with\nmore kindness than might have been expected of him:\n\n\'Oh, you must not talk about dying yet.\'\n\n\'Lor bless her dear heart, no!\' interposed the nurse, hastily\ndepositing in her pocket a green glass bottle, the contents of which\nshe had been tasting in a corner with evident satisfaction.\n\n\'Lor bless her dear heart, when she has lived as long as I have, sir,\nand had thirteen children of her own, and all on \'em dead except two,\nand them in the wurkus with me, she\'ll know better than to take on in\nthat way, bless her dear heart!  Think what it is to be a mother,\nthere\'s a dear young lamb do.\'\n\nApparently this consolatory perspective of a mother\'s prospects failed\nin producing its due effect.  The patient  ...

# %% [markdown]
# ### Tokenize and Clean Text

# %%
# Import standard libraries
import spacy
nlp = spacy.load('en',disable=['parser', 'tagger','ner'])
# Increase the allowable max lentgh
nlp.max_length = 1198623

# %%
# Run this function to seperate punctuations
def separate_punc(doc_text):
    
    return [token.text.lower() for token in nlp(doc_text) if token.text not in '\n\n \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_`{|}~\t\n ']
tokens = separate_punc(fields)

# %% [markdown]
# ### Create Sequences of Tokens

# %%
# organize into sequences of tokens
train_len = 25+1 # 50 training words , then one target word

# Empty list of sequences
text_sequences = []

for i in range(train_len, len(tokens)):
    
    # Grab train_len# amount of characters
    seq = tokens[i-train_len:i]
    
    # Add to list of sequences
    text_sequences.append(seq)

# %%
text_sequences[0]
# Out:
# ['treats',
#  'of',
#  'the',
#  'place',
#  'where',
#  'oliver',
#  'twist',
#  'was',
#  'born',
#  'and',
#  'of',
#  'the',
#  'circumstances',
#  'attending',
#  'his',
#  'birth',
#  'among',
#  'other',
#  'public',
#  'buildings',
#  'in',
#  'a',
#  'certain',
#  'town',
#  'which',
#  'for']

# %% [markdown]
# ### Keras Tokenization

# %%
from keras.preprocessing.text import Tokenizer
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_sequences)
sequences = tokenizer.texts_to_sequences(text_sequences)

# %%
vocabulary_size = len(tokenizer.word_counts)
sequences = np.array(sequences)

# %%
sequences[0]
# Out:
# array([1285,    5,    1,  162,  139,   11,  126,   10,  596,    3,    5,
#           1,  728, 4371,    8, 1283,  510,   98,  270, 4370,    9,    4,
#         930,  727,   27,   21])

# %%
for i in sequences[0]:
    print(f'{i} : {tokenizer.index_word[i]}')
# Out:
# 1285 : treats
# 5 : of
# 1 : the
# 162 : place
# 139 : where
# 11 : oliver
# 126 : twist
# 10 : was
# 596 : born
# 3 : and
# 5 : of
# 1 : the
# 728 : circumstances
# 4371 : attending
# 8 : his
# 1283 : birth
# 510 : among
# 98 : other
# 270 : public
# 4370 : buildings
# 9 : in
# 4 : a
# 930 : certain
# 727 : town
# 27 : which
# 21 : for

# %% [markdown]
# ### Creating an LSTM based model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,LSTM,Embedding

# %%
# create your own custom model
def create_model(vocabulary_size, seq_len):
    
    model = Sequential()
    model.add(Embedding(vocabulary_size, 25, input_length=seq_len))
    #this has to always be the firstb layer
    #we are defining an input dimension for the embedding which is the entirety of the vocabulary and also the output dimension which is just the sequence length.
    #all what embedding is doing is to turn postive integers or indexes into dense vector of a fixed size(which is similar to normalizing or reducing the values into an integer below 1)
    #eg. [[4], [20]] -> [[0.6, -0.2]]
    model.add(LSTM(150, return_sequences=True))
    #we are using 150 neurons but will be slower compare to 50 neurons
    model.add(LSTM(150)) #another layer
    model.add(Dense(150, activation='relu')) #dense layer
    #we want to translate into vocabulary words because is just going to split out a number
    #so we want a dense network of our vocabulary size where the activation is soft max 
    model.add(Dense(vocabulary_size, activation='softmax'))
    #categorical_crossentropy means we are treating each vocabulary word as it's own individual category
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
   
    model.summary()
    
    return model

# %%
from keras.utils import to_categorical

# %%
# Train / Test Split
X = sequences[:,:-1]
y = sequences[:,-1]
y = to_categorical(y, num_classes=vocabulary_size+1)
seq_len = X.shape[1]

# %%
from pickle import dump,load

# %%
# define model
model = create_model(vocabulary_size+1, seq_len)
# fit model
model.fit(X, y, batch_size=128, epochs=30,verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\Maxwell\Anaconda3\envs\nlp_course\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None,