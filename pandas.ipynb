# %%
#Question One

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# u'0.24.2'

# %%
#Question 2

# %%
Csv1 = pd.read_csv("Csv1.csv")

# %%
Csv2 = pd.read_csv("Csv2.csv")

# %%
len(Csv1)
# Out:
# 119

# %%
len(Csv2)
# Out:
# 115

# %%
#Question 3

# %%
Csv3 = pd.merge(Csv1, Csv2, left_index=True, right_index=True)
Csv3
# Out:
#      Address.City_x  ID_x LocationMilestones.LastRemodelDate  \
# 0            Oxford  2153                                NaN
# 1           Opelika  1499                                NaN
# 2        Carrollton  1073                                NaN
# 3            Newnan  1223                2013-06-27T12:00:00
# 4          Columbus  1179                2004-10-17T12:00:00
# 5    Peachtree City  2129                2013-10-10T12:00:00
# 6        Montgomery  1825                2014-04-03T12:00:00
# 7      Douglasville  1172                                NaN
# 8        Prattville  2274                                NaN
# 9        Birmingham  1772                                NaN
# 10     Fayetteville   778                2007-10-18T12:00:00
# 11       Birmingham  1773                                NaN
# 12            Hiram  1400                                NaN
# 13        Alabaster  2276                                NaN
# ...

# %%
#Question 4

# %%
Csv3.shape
# Out:
# (115, 16)

# %%
Csv3.dtypes
# Out:
# Address.City_x                        object
# ID_x                                   int64
# LocationMilestones.LastRemodelDate    object
# LocationMilestones.OpenDate           object
# Name_x                                object
# Store.StoreDistrictID                  int64
# TimeZone.TimeZoneCode                 object
# PhoneNumber                           object
# Address.City_y                        object
# ID_y                                   int64
# Name_y                                object
# FaxNumber                             object
# BeginTime.MF                          object
# ThruTime.MF                           object
# IsOpen.Sat                              bool
# IsOpen.Sun                              bool
# dtype: object

# %%
Csv3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 0 to 114
# Data columns (total 16 columns):
# Address.City_x                        115 non-null object
# ID_x                                  115 non-null int64
# LocationMilestones.LastRemodelDate    77 non-null object
# LocationMilestones.OpenDate           115 non-null object
# Name_x                                115 non-null object
# Store.StoreDistrictID                 115 non-null int64
# TimeZone.TimeZoneCode                 115 non-null object
# PhoneNumber                           115 non-null object
# Address.City_y                        115 non-null object
# ID_y                                  115 non-null int64
# Name_y                                115 non-null object
# FaxNumber                             110 non-null object
# BeginTime.MF                          115 non-null object
# ThruTime.MF                           115 non-null object
# ...

# %%
Csv3.values
# Out:
# array([['Oxford', 2153L, nan, ..., '22:00:00', True, False],
#        ['Opelika', 1499L, nan, ..., '22:00:00', False, True],
#        ['Carrollton', 1073L, nan, ..., '22:00:00', True, True],
#        ...,
#        ['Hesperia', 2468L, nan, ..., '22:00:00', True, True],
#        ['Grand Junction', 93L, '2014-10-12T12:00:00', ..., '23:00:00',
#         True, False],
#        ['Montrose', 2343L, nan, ..., '23:00:00', True, False]],
#       dtype=object)

# %%
List(Csv3.values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-306-4b95adf1a4f1> in <module>()
# ----> 1 List(Csv3.values)
#
# TypeError: 'list' object is not callable

# %%
#Question 5

# %%
Csv3.rename(columns = {"Name" :"Store Name"}, inplace = True)
Csv3
# Out:
#      Address.City_x  ID_x LocationMilestones.LastRemodelDate  \
# 0            Oxford  2153                                NaN
# 1           Opelika  1499                                NaN
# 2        Carrollton  1073                                NaN
# 3            Newnan  1223                2013-06-27T12:00:00
# 4          Columbus  1179                2004-10-17T12:00:00
# 5    Peachtree City  2129                2013-10-10T12:00:00
# 6        Montgomery  1825                2014-04-03T12:00:00
# 7      Douglasville  1172                                NaN
# 8        Prattville  2274                                NaN
# 9        Birmingham  1772                                NaN
# 10     Fayetteville   778                2007-10-18T12:00:00
# 11       Birmingham  1773                                NaN
# 12            Hiram  1400                                NaN
# 13        Alabaster  2276                                NaN
# ...

# %%
#Question 6

# %%
missing_values = ["n/a", "na", "--"]
df = pd.read_csv("Csv1.csv", na_values = missing_values)

# %%
#print df.isnull().sum()

# %%
missing_values = ["n/a", "na", "--"]
df = pd.read_csv("Csv2.csv", na_values = missing_values)

# %%
#print df.isnull().sum()

# %%
df.isnull().values.any()
# Out:
# True

# %%
print df.isnull().sum().sum()
# Out:
# 5

# %%
#Question 7

# %%
from math import pi

import pandas as pd

from bokeh.io import output_file, show
from bokeh.palettes import Category20c
from bokeh.plotting import figure
from bokeh.transform import cumsum

# %%
#Question 8

# %%
#Csv3[Csv3["ThruTime.MF"]== "23:00"]

# %%
Csv3["ThruTime.MF"] = pd.to_datetime(Csv3["ThruTime.MF"])
#Csv3["ThruTime.MF"]

# %%
#Question 9

# %%
Csv3["LocationMilestones.LastRemodelDate"] = pd.to_datetime(Csv3["LocationMilestones.LastRemodelDate"])
Csv3["LocationMilestones.LastRemodelDate"]
# Out:
# 0                     NaT
# 1                     NaT
# 2                     NaT
# 3     2013-06-27 12:00:00
# 4     2004-10-17 12:00:00
# 5     2013-10-10 12:00:00
# 6     2014-04-03 12:00:00
# 7                     NaT
# 8                     NaT
# 9                     NaT
# 10    2007-10-18 12:00:00
# 11                    NaT
# 12                    NaT
# 13                    NaT
# 14    2012-06-21 12:00:00
# 15                    NaT
# 16    2004-08-08 12:00:00
# 17                    NaT
# 18    2013-06-27 12:00:00
# 19                    NaT
# 20                    NaT
# 21                    NaT
# 22    2012-03-22 12:00:00
# 23    2012-03-22 12:00:00
# 24    2012-03-22 12:00:00
# 25                    NaT
# 26    2012-06-21 12:00:00
# 27    2012-06-21 12:00:00
# 28    2017-03-30 12:00:00
# 29    2012-06-21 12:00:00
#               ...
# 85    2012-06-21 12:00:00
# 86    2014-04-03 12:00:00
# 87    2012-06-21 12:00:00
# 88    2012-06-21 12:00:00
# 89                    NaT
# ...

# %%
CF = Csv3[Csv3["LocationMilestones.LastRemodelDate"].notnull()]

# %%
CF.set_index("LocationMilestones.LastRemodelDate").to_dict()
# Out:
# {'Address.City_x': {Timestamp('2000-03-01 12:00:00'): 'Roswell',
#   Timestamp('2003-08-12 12:00:00'): 'Mobile',
#   Timestamp('2004-08-08 12:00:00'): 'Maryville',
#   Timestamp('2004-09-19 12:00:00'): 'Marietta',
#   Timestamp('2004-10-17 12:00:00'): 'Columbus',
#   Timestamp('2006-05-12 12:00:00'): 'Aiken',
#   Timestamp('2007-03-23 12:00:00'): 'Madison',
#   Timestamp('2007-04-13 12:00:00'): 'Warner Robins',
#   Timestamp('2007-07-13 12:00:00'): 'Florence',
#   Timestamp('2007-10-18 12:00:00'): 'Fayetteville',
#   Timestamp('2009-07-09 12:00:00'): 'Tallahassee',
#   Timestamp('2010-10-14 12:00:00'): 'Nashville',
#   Timestamp('2011-06-02 12:00:00'): 'Palm Desert',
#   Timestamp('2011-10-06 12:00:00'): 'Apple Valley',
#   Timestamp('2012-03-22 12:00:00'): 'Asheville',
#   Timestamp('2012-06-21 12:00:00'): 'Spartanburg',
#   Timestamp('2012-10-11 12:00:00'): 'Hendersonville',
#   Timestamp('2013-03-21 12:00:00'): 'Atlanta',
#   Timestamp('2013-06-27 12:00:00'): 'Mary Esther',
# ...

# %%
#Question 10

# %%
gk1 = Csv(3.groupby("Address.City_x"))
gk2 = Csv3.groupby("Address.City_y")

# %%
gk1.first()
gk1.get_group("Alabaster")

# %%
#gk1.size()
#gk2.size()

# %%
#Question 11

# %%
TIME = pd.date_range(start = "1980-10-27", end = "2007-03-07", freq = "A")
TIME
# Out:
# DatetimeIndex(['1980-12-31', '1981-12-31', '1982-12-31', '1983-12-31',
#                '1984-12-31', '1985-12-31', '1986-12-31', '1987-12-31',
#                '1988-12-31', '1989-12-31', '1990-12-31', '1991-12-31',
#                '1992-12-31', '1993-12-31', '1994-12-31', '1995-12-31',
#                '1996-12-31', '1997-12-31', '1998-12-31', '1999-12-31',
#                '2000-12-31', '2001-12-31', '2002-12-31', '2003-12-31',
#                '2004-12-31', '2005-12-31', '2006-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
type(TIME)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
s = pd.Series(TIME)
s.head(3)
# Out:
# 0   1980-12-31
# 1   1981-12-31
# 2   1982-12-31
# dtype: datetime64[ns]
